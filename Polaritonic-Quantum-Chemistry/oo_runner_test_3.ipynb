# %% [markdown]
# ## This tests the QED-RHF gradient components against Hilbert's and against numerical components

# %%
from oo_cqed_rhf import CQEDRHFCalculator
import numpy as np
import psi4

# %% [markdown]
# ### Expected O_DSE gradient term from Hilbert

# %%
_expected_o_dse = np.array(
[[ 4.50564203e-20,  1.34441069e-18, -2.74087275e-03],
 [-5.50477740e-20,  1.05859828e-04,  1.82095121e-03],
 [ 9.99135370e-21, -1.05859828e-04,  1.82095121e-03]]
)

# %% [markdown]
# ### Expected K_DSE gradient term from Hilbert

# %%
_expected_k_dse = np.array(
[[ 1.14641991e-19, -1.20129601e-18,  8.09949008e-04],
 [-5.05409763e-20, -3.61148015e-04, -8.55489341e-04],
 [-6.41010149e-20,  3.61148015e-04, -8.55489341e-04]]
)

# %%
# Expected gradient contributions for Water in a STO-3G basis set with the following geometry:
h2o_string = """
         O            0.000000000000     0.000000000000    -0.068516219320
         H            0.000000000000    -0.790689573744     0.543701060715
         H            0.000000000000     0.790689573744     0.543701060715
no_reorient
nocom
symmetry c1
"""

w = 0.07349864501573
# lambda: 0.05
# coupling g = 0.05 / sqrt(2*w)
g = 0.05 / np.sqrt(2.0 * w)

# no cavity
lambda_vector = np.array([0, 0, 0.05])
print(lambda_vector)
# options for H2O
psi4_options = {
    "basis": "sto-3g",
    "save_jk": True,
    "scf_type": "pk",
    "e_convergence": 1e-12,
    "d_convergence": 1e-12,
}
# Out:
# [0.   0.   0.05]

# %%
calc = CQEDRHFCalculator(lambda_vector, h2o_string, psi4_options)
calc.calc_cqed_rhf_energy()
# Out:
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:46 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.068516219320    15.994914619570
#          H            0.000000000000    -0.790689573744     0.543701060715     1.007825032230
#          H            0.000000000000     0.790689573744     0.543701060715     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12555  B =     13.37733  C =      8.72955 [cm^-1]
#   Rotational constants: A = 753245.07149  B = 401042.16706  C = 261705.25473 [MHz]
#   Nuclear repulsion =    8.801465564563406
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028400386E-01.
#   Reciprocal condition number of the overlap matrix is 1.9726983142E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12089031243625   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998617813378   -7.89096e-01   3.66864e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355634955587   -5.35702e-02   5.93741e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458413700164   -1.02779e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466116166594   -7.70247e-05   1.32272e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466252758711   -1.36592e-06   1.29980e-05 DIIS
#    @RHF iter   6:   -74.96466253910351   -1.15164e-08   1.58451e-07 DIIS
#    @RHF iter   7:   -74.96466253910495   -1.43530e-12   8.95253e-10 DIIS
#    @RHF iter   8:   -74.96466253910495    0.00000e+00   9.54681e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247270     2A     -1.247775     3A     -0.595851
#        4A     -0.447884     5A     -0.388956
#
#     Virtual:
#
#        6A      0.564152     7A      0.693007
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466253910495
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014655645634061
#     One-Electron Energy =                -121.6767825482262708
#     Two-Electron Energy =                  37.9106544445579345
#     Total Energy =                        -74.9646625391049355
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -0.3624478            1.0190771            0.6566293
#  Magnitude           :                                                    0.6566293
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:47 2025
# Module time:
# 	user time   =       0.32 seconds =       0.01 minutes
# 	system time =       0.10 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       0.32 seconds =       0.01 minutes
# 	system time =       0.10 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes

# %%
calc.summary()
# Out:
# RHF Energy:           -74.96466254 Ha
# CQED-RHF Energy:      -74.96009499 Ha
# Dipole Energy:        0.00016237 Ha
# Nuclear Repulsion:    8.80146556 Ha
# Dipole Moment:        [4.88077911e-17 3.24153496e-15 6.58665211e-01]

# %%
calc.compute_canonical_gradients()

# %%
# print the total gradient
print(calc.canonical_gradient)
# Out:
# [[-3.04967191e-16  4.65412344e-16  1.05402411e-03]
#  [ 1.73832759e-16 -1.93839853e-02 -5.27012056e-04]
#  [ 1.31134432e-16  1.93839853e-02 -5.27012056e-04]]

# %%
# use psi4 to compute the gradient
calc.calc_scf_gradient(qed_wfn=True)
# Out:
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:51 2025
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.068516219320    15.994914619570
#          H            0.000000000000    -0.790689573744     0.543701060715     1.007825032230
#          H            0.000000000000     0.790689573744     0.543701060715     1.007825032230
#
#   Nuclear repulsion =    8.801465564563406
#
#   ==> Basis Set <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.000000000000     0.000000000000     0.001054024113
#        2        0.000000000000    -0.019383985260    -0.000527012057
#        3        0.000000000000     0.019383985260    -0.000527012057
#
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:51 2025
# Module time:
# 	user time   =       0.00 seconds =       0.00 minutes
# 	system time =       0.00
# array([[-3.04967191e-16,  6.63518455e-16,  1.05402411e-03],
#        [ 1.73832759e-16, -1.93839853e-02, -5.27012057e-04],
#        [ 1.31134432e-16,  1.93839853e-02, -5.27012057e-04]])
#  seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.36 seconds =       0.01 minutes
# 	system time =       0.10 seconds =       0.00 minutes
# 	total time  =          5 seconds =       0.08 minutes

# %%
#print(calc.scf_grad)
# compute the numerical gradient
calc.calc_numerical_gradient()
# Out:
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:51 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000010000000     0.000000000000    -0.068516220000    15.994914619570
#          H            0.000000000000    -0.790689570000     0.543701060000     1.007825032230
#          H            0.000000000000     0.790689570000     0.543701060000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12555  B =     13.37733  C =      8.72955 [cm^-1]
#   Rotational constants: A = 753245.06978  B = 401042.17041  C = 261705.25634 [MHz]
#   Nuclear repulsion =    8.801465590970723
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028400192E-01.
#   Reciprocal condition number of the overlap matrix is 1.9726982991E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12089031924612   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998617869377   -7.89096e-01   3.66864e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355634984610   -5.35702e-02   5.93741e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458413727737   -1.02779e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466116194040   -7.70247e-05   1.32272e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466252786156   -1.36592e-06   1.29980e-05 DIIS
#    @RHF iter   6:   -74.96466253937793   -1.15164e-08   1.58451e-07 DIIS
#    @RHF iter   7:   -74.96466253937945   -1.52056e-12   8.95253e-10 DIIS
#    @RHF iter   8:   -74.96466253937946   -1.42109e-14   9.58548e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247270     2A     -1.247775     3A     -0.595851
#        4A     -0.447884     5A     -0.388956
#
#     Virtual:
#
#        6A      0.564152     7A      0.693007
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466253937946
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014655909707233
#     One-Electron Energy =                -121.6767825936508132
#     Two-Electron Energy =                  37.9106544633006450
#     Total Energy =                        -74.9646625393794466
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0001619            0.0001512           -0.0000107
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.3624478            1.0190771            0.6566293
#  Magnitude           :                                                    0.6566293
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:51 2025
# Module time:
# 	user time   =       0.06 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.46 seconds =       0.01 minutes
# 	system time =       0.12 seconds =       0.00 minutes
# 	total time  =          5 seconds =       0.08 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:51 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O           -0.000010000000     0.000000000000    -0.068516220000    15.994914619570
#          H            0.000000000000    -0.790689570000     0.543701060000     1.007825032230
#          H            0.000000000000     0.790689570000     0.543701060000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12555  B =     13.37733  C =      8.72955 [cm^-1]
#   Rotational constants: A = 753245.06978  B = 401042.17041  C = 261705.25634 [MHz]
#   Nuclear repulsion =    8.801465590970723
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028400192E-01.
#   Reciprocal condition number of the overlap matrix is 1.9726982991E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12089031924612   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998617869371   -7.89096e-01   3.66864e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355634984604   -5.35702e-02   5.93741e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458413727730   -1.02779e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466116194046   -7.70247e-05   1.32272e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466252786158   -1.36592e-06   1.29980e-05 DIIS
#    @RHF iter   6:   -74.96466253937797   -1.15164e-08   1.58451e-07 DIIS
#    @RHF iter   7:   -74.96466253937947   -1.50635e-12   8.95251e-10 DIIS
#    @RHF iter   8:   -74.96466253937945    2.84217e-14   9.63024e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247270     2A     -1.247775     3A     -0.595851
#        4A     -0.447884     5A     -0.388956
#
#     Virtual:
#
#        6A      0.564152     7A      0.693007
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466253937945
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014655909707233
#     One-Electron Energy =                -121.6767825936507137
#     Two-Electron Energy =                  37.9106544633005456
#     Total Energy =                        -74.9646625393794466
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0001619           -0.0001512            0.0000107
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.3624478            1.0190771            0.6566293
#  Magnitude           :                                                    0.6566293
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:51 2025
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.52 seconds =       0.01 minutes
# 	system time =       0.12 seconds =       0.00 minutes
# 	total time  =          5 seconds =       0.08 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:52 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000010000000    -0.068516220000    15.994914619570
#          H            0.000000000000    -0.790689570000     0.543701060000     1.007825032230
#          H            0.000000000000     0.790689570000     0.543701060000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12555  B =     13.37733  C =      8.72955 [cm^-1]
#   Rotational constants: A = 753245.07181  B = 401042.17029  C = 261705.25614 [MHz]
#   Nuclear repulsion =    8.801465591764730
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028400148E-01.
#   Reciprocal condition number of the overlap matrix is 1.9726982967E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12089031945060   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998617854676   -7.89096e-01   3.66864e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355634970250   -5.35702e-02   5.93741e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458413713380   -1.02779e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466116179688   -7.70247e-05   1.32272e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466252771802   -1.36592e-06   1.29980e-05 DIIS
#    @RHF iter   6:   -74.96466253923431   -1.15163e-08   1.58451e-07 DIIS
#    @RHF iter   7:   -74.96466253923593   -1.62004e-12   8.96843e-10 DIIS
#    @RHF iter   8:   -74.96466253923592    1.42109e-14   1.92615e-11 DIIS
#    @RHF iter   9:   -74.96466253923589    2.84217e-14   6.33435e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247270     2A     -1.247775     3A     -0.595851
#        4A     -0.447884     5A     -0.388956
#
#     Virtual:
#
#        6A      0.564152     7A      0.693007
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466253923589
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014655917647300
#     One-Electron Energy =                -121.6767825948302146
#     Two-Electron Energy =                  37.9106544638296015
#     Total Energy =                        -74.9646625392358885
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :         -0.0001516            0.0001512           -0.0000004
#  Dipole Z            :         -0.3624478            1.0190771            0.6566293
#  Magnitude           :                                                    0.6566293
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:52 2025
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.57 seconds =       0.01 minutes
# 	system time =       0.12 seconds =       0.00 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:52 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000    -0.000010000000    -0.068516220000    15.994914619570
#          H            0.000000000000    -0.790689570000     0.543701060000     1.007825032230
#          H            0.000000000000     0.790689570000     0.543701060000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12555  B =     13.37733  C =      8.72955 [cm^-1]
#   Rotational constants: A = 753245.07181  B = 401042.17029  C = 261705.25614 [MHz]
#   Nuclear repulsion =    8.801465591764730
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028400148E-01.
#   Reciprocal condition number of the overlap matrix is 1.9726982967E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12089031945061   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998617854665   -7.89096e-01   3.66864e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355634970246   -5.35702e-02   5.93741e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458413713376   -1.02779e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466116179690   -7.70247e-05   1.32272e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466252771789   -1.36592e-06   1.29980e-05 DIIS
#    @RHF iter   6:   -74.96466253923433   -1.15164e-08   1.58451e-07 DIIS
#    @RHF iter   7:   -74.96466253923582   -1.49214e-12   8.96849e-10 DIIS
#    @RHF iter   8:   -74.96466253923582    0.00000e+00   1.92608e-11 DIIS
#    @RHF iter   9:   -74.96466253923579    2.84217e-14   6.39914e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247270     2A     -1.247775     3A     -0.595851
#        4A     -0.447884     5A     -0.388956
#
#     Virtual:
#
#        6A      0.564152     7A      0.693007
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466253923579
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014655917647300
#     One-Electron Energy =                -121.6767825948302431
#     Two-Electron Energy =                  37.9106544638297223
#     Total Energy =                        -74.9646625392358033
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0001516           -0.0001512            0.0000004
#  Dipole Z            :         -0.3624478            1.0190771            0.6566293
#  Magnitude           :                                                    0.6566293
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:52 2025
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.63 seconds =       0.01 minutes
# 	system time =       0.13 seconds =       0.00 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:52 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.068506220000    15.994914619570
#          H            0.000000000000    -0.790689570000     0.543701060000     1.007825032230
#          H            0.000000000000     0.790689570000     0.543701060000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12637  B =     13.37733  C =      8.72965 [cm^-1]
#   Rotational constants: A = 753269.67770  B = 401042.17086  C = 261708.22656 [MHz]
#   Nuclear repulsion =    8.801517426876410
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028009746E-01.
#   Reciprocal condition number of the overlap matrix is 1.9726727964E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12090365879889   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998725070747   -7.89084e-01   3.66862e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355635261722   -5.35691e-02   5.93728e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458410334890   -1.02775e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466112871104   -7.70254e-05   1.32276e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466249472378   -1.36601e-06   1.29971e-05 DIIS
#    @RHF iter   6:   -74.96466250623813   -1.15143e-08   1.58511e-07 DIIS
#    @RHF iter   7:   -74.96466250623958   -1.44951e-12   8.95615e-10 DIIS
#    @RHF iter   8:   -74.96466250623963   -5.68434e-14   9.58586e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247268     2A     -1.247776     3A     -0.595856
#        4A     -0.447883     5A     -0.388956
#
#     Virtual:
#
#        6A      0.564156     7A      0.693017
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466250623963
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8015174268764103
#     One-Electron Energy =                -121.6768817477102118
#     Two-Electron Energy =                  37.9107018145941694
#     Total Energy =                        -74.9646625062396197
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.3625977            1.0192282            0.6566305
#  Magnitude           :                                                    0.6566305
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:52 2025
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.69 seconds =       0.01 minutes
# 	system time =       0.13 seconds =       0.00 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:52 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.068526220000    15.994914619570
#          H            0.000000000000    -0.790689570000     0.543701060000     1.007825032230
#          H            0.000000000000     0.790689570000     0.543701060000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12473  B =     13.37733  C =      8.72945 [cm^-1]
#   Rotational constants: A = 753220.46347  B = 401042.17086  C = 261702.28579 [MHz]
#   Nuclear repulsion =    8.801413756017071
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028790637E-01.
#   Reciprocal condition number of the overlap matrix is 1.9727238018E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12087697993837   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998510647705   -7.89108e-01   3.66867e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355634686076   -5.35712e-02   5.93754e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458417099689   -1.02782e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466119496102   -7.70240e-05   1.32267e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466256079053   -1.36583e-06   1.29989e-05 DIIS
#    @RHF iter   6:   -74.96466257230888   -1.15184e-08   1.58390e-07 DIIS
#    @RHF iter   7:   -74.96466257231032   -1.43530e-12   8.94893e-10 DIIS
#    @RHF iter   8:   -74.96466257231029    2.84217e-14   9.52812e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247272     2A     -1.247773     3A     -0.595847
#        4A     -0.447886     5A     -0.388957
#
#     Virtual:
#
#        6A      0.564148     7A      0.692998
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466257231029
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014137560170713
#     One-Electron Energy =                -121.6766834412789819
#     Two-Electron Energy =                  37.9106071129516096
#     Total Energy =                        -74.9646625723103028
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.3622978            1.0189259            0.6566281
#  Magnitude           :                                                    0.6566281
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:52 2025
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.74 seconds =       0.01 minutes
# 	system time =       0.13 seconds =       0.00 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:52 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.068516220000    15.994914619570
#          H            0.000010000000    -0.790689570000     0.543701060000     1.007825032230
#          H            0.000000000000     0.790689570000     0.543701060000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12555  B =     13.37733  C =      8.72955 [cm^-1]
#   Rotational constants: A = 753245.07152  B = 401042.17084  C = 261705.25635 [MHz]
#   Nuclear repulsion =    8.801465591175704
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028400190E-01.
#   Reciprocal condition number of the overlap matrix is 1.9726982990E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12089031929878   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998617869792   -7.89096e-01   3.66864e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355634984477   -5.35702e-02   5.93741e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458413727588   -1.02779e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466116193899   -7.70247e-05   1.32272e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466252786016   -1.36592e-06   1.29980e-05 DIIS
#    @RHF iter   6:   -74.96466253937652   -1.15164e-08   1.58451e-07 DIIS
#    @RHF iter   7:   -74.96466253937798   -1.46372e-12   8.95254e-10 DIIS
#    @RHF iter   8:   -74.96466253937800   -1.42109e-14   9.55569e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247270     2A     -1.247775     3A     -0.595851
#        4A     -0.447884     5A     -0.388956
#
#     Virtual:
#
#        6A      0.564152     7A      0.693007
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466253937800
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014655911757043
#     One-Electron Energy =                -121.6767825940643633
#     Two-Electron Energy =                  37.9106544635106673
#     Total Energy =                        -74.9646625393779971
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000135            0.0000189            0.0000054
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.3624478            1.0190771            0.6566293
#  Magnitude           :                                                    0.6566293
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:52 2025
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.80 seconds =       0.01 minutes
# 	system time =       0.14 seconds =       0.00 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:52 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
# ...
#    @RHF iter   6:   -74.96466290553005   -1.15153e-08   1.58475e-07 DIIS
#    @RHF iter   7:   -74.96466290553153   -1.47793e-12   8.95762e-10 DIIS
#    @RHF iter   8:   -74.96466290553150    2.84217e-14   9.67041e-12 DIIS
#    @RHF iter   9:   -74.96466290553151   -1.42109e-14   5.96275e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247270     2A     -1.247777     3A     -0.595853
#        4A     -0.447886     5A     -0.388957
#
#     Virtual:
#
#        6A      0.564157     7A      0.693011
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466290553151
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8015011808507424
#     One-Electron Energy =                -121.6768438757085846
#     Two-Electron Energy =                  37.9106797893263305
#     Total Energy =                        -74.9646629055314975
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000187           -0.0000189           -0.0000002
#  Dipole Z            :         -0.3624449            1.0190771            0.6566322
#  Magnitude           :                                                    0.6566322
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:52 2025
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       1.31 seconds =       0.02 minutes
# 	system time =       0.17 seconds =       0.00 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:52 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.068516220000    15.994914619570
#          H            0.000000000000    -0.790689570000     0.543701060000     1.007825032230
#          H            0.000000000000     0.790689570000     0.543711060000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12514  B =     13.37733  C =      8.72950 [cm^-1]
#   Rotational constants: A = 753232.76823  B = 401042.17083  C = 261703.77116 [MHz]
#   Nuclear repulsion =    8.801439673698878
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028595406E-01.
#   Reciprocal condition number of the overlap matrix is 1.9727110500E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12088364964487   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998564259282   -7.89102e-01   3.66866e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355634835732   -5.35707e-02   5.93747e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458415414028   -1.02781e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466117845381   -7.70243e-05   1.32269e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466254432913   -1.36588e-06   1.29985e-05 DIIS
#    @RHF iter   6:   -74.96466255584653   -1.15174e-08   1.58420e-07 DIIS
#    @RHF iter   7:   -74.96466255584808   -1.54898e-12   8.95318e-10 DIIS
#    @RHF iter   8:   -74.96466255584799    8.52651e-14   7.51221e-12 DIIS
#    @RHF iter   9:   -74.96466255584801   -1.42109e-14   5.90336e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247271     2A     -1.247774     3A     -0.595849
#        4A     -0.447885     5A     -0.388957
#
#     Virtual:
#
#        6A      0.564150     7A      0.693003
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466255584801
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014396736988783
#     One-Electron Energy =                -121.6767330178868320
#     Two-Electron Energy =                  37.9106307883399367
#     Total Energy =                        -74.9646625558480082
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :         -0.0000040            0.0000000           -0.0000040
#  Dipole Z            :         -0.3624673            1.0190960            0.6566287
#  Magnitude           :                                                    0.6566287
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:52 2025
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       1.37 seconds =       0.02 minutes
# 	system time =       0.17 seconds =       0.00 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Tue Jun 17 20:46:52 2025
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line    81 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#     atoms 2-3 entry H          line    19 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/sto-3g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.068516220000    15.994914619570
#          H            0.000000000000    -0.790689570000     0.543701060000     1.007825032230
#          H            0.000000000000     0.790689570000     0.543691060000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.12596  B =     13.37733  C =      8.72960 [cm^-1]
#   Rotational constants: A = 753257.37535  B = 401042.17083  C = 261706.74155 [MHz]
#   Nuclear repulsion =    8.801491509128548
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: STO-3G
#     Blend: STO-3G
#     Number of shells: 5
#     Number of basis functions: 7
#     Number of Cartesian functions: 7
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:               5
#       Number of primitives:             15
#       Number of atomic orbitals:         7
#       Number of basis functions:         7
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 812 doubles for integral storage.
#   We computed 120 shell quartets total.
#   Whereas there are 120 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7028204961E-01.
#   Reciprocal condition number of the overlap matrix is 1.9726855473E-01.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A          7       7
#    -------------------------
#     Total       7       7
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -74.12089698907512   -7.41209e+01   0.00000e+00
#    @RHF iter   1:   -74.90998671470807   -7.89090e-01   3.66863e-02 DIIS/ADIIS
#    @RHF iter   2:   -74.96355635123558   -5.35696e-02   5.93734e-03 DIIS/ADIIS
#    @RHF iter   3:   -74.96458412031626   -1.02777e-03   1.32273e-03 DIIS/ADIIS
#    @RHF iter   4:   -74.96466114532886   -7.70250e-05   1.32274e-04 DIIS/ADIIS
#    @RHF iter   5:   -74.96466251129590   -1.36597e-06   1.29976e-05 DIIS
#    @RHF iter   6:   -74.96466252281120   -1.15153e-08   1.58481e-07 DIIS
#    @RHF iter   7:   -74.96466252281270   -1.50635e-12   8.95668e-10 DIIS
#    @RHF iter   8:   -74.96466252281276   -5.68434e-14   7.51272e-12 DIIS
#    @RHF iter   9:   -74.96466252281276    0.00000e+00   5.95830e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.247269     2A     -1.247775     3A     -0.595853
#        4A     -0.447884     5A     -0.388956
#
#     Virtual:
#
#        6A      0.564154     7A      0.693012
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -74.96466252281276
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014915091285477
#     One-Electron Energy =                -121.6768321711028875
#     Two-Electron Energy =                  37.9106781391615684
#     Total Energy =                        -74.9646625228127732
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000040            0.0000000            0.0000040
#  Dipole Z            :         -0.3624283            1.0190582            0.6566299
#  Magnitude           :                                                    0.6566299
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Tue Jun 17 20:46:52 2025
# Module time:
# 	user time   =       0.05 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       1.43 seconds =       0.02 minutes
# 	system time =       0.17 seconds =       0.00 minutes
# 	total time  =          6 seconds =       0.10 minutes

# %%
print(F" My Analytical Gradient Matches Psi4's Gradient: {np.allclose(calc.scf_grad, calc.canonical_gradient, 1e-6, 1e-6)}")
error_norm = np.linalg.norm(calc.scf_grad-  calc.canonical_gradient)
print(F" Norm of difference is {error_norm}")

print(F" Numerical Gradient Matches Psi4's Gradient: {np.allclose(calc.numerical_energy_gradient.reshape(3,3), calc.canonical_gradient, 1e-6, 1e-6)}")
error_norm = np.linalg.norm(calc.numerical_energy_gradient.reshape(3,3)-  calc.canonical_gradient)
print(F" Norm of difference is {error_norm}")


print(F" Numerical Gradient Matches Psi4's Gradient: {np.allclose(calc.numerical_scf_gradient.reshape(3,3), calc.canonical_gradient, 1e-6, 1e-6)}")
error_norm = np.linalg.norm(calc.numerical_scf_gradient.reshape(3,3)-  calc.canonical_gradient)
print(F" Norm of difference is {error_norm}")
# Out:
#  My Analytical Gradient Matches Psi4's Gradient: True
#  Norm of difference is 9.912797637962686e-13
#  Numerical Gradient Matches Psi4's Gradient: False
#  Norm of difference is 0.002392285847019441
#  Numerical Gradient Matches Psi4's Gradient: False
#  Norm of difference is 0.0008459788936484209

# %%
calc.calc_quadrupole_gradient()
# Out:
# [[-8.50179782e-20 -6.75097808e-09 -2.74088600e-03]
#  [ 1.23594531e-19  1.05862536e-04  1.82095059e-03]
#  [-3.85765526e-20 -1.05855785e-04  1.82091640e-03]]

# %%
print("my o_dse gradient")
print(calc.o_dse_gradient.reshape(3,3))
# Out:
# my o_dse gradient
# [[-8.50179782e-20 -6.75097808e-09 -2.74088600e-03]
#  [ 1.23594531e-19  1.05862536e-04  1.82095059e-03]
#  [-3.85765526e-20 -1.05855785e-04  1.82091640e-03]]

# %%
print("Expected o_dse gradient")
print(_expected_o_dse)
# Out:
# Expected o_dse gradient
# [[ 4.50564203e-20  1.34441069e-18 -2.74087275e-03]
#  [-5.50477740e-20  1.05859828e-04  1.82095121e-03]
#  [ 9.99135370e-21 -1.05859828e-04  1.82095121e-03]]

# %%
calc.hilber_quadrupole_gradient()
print("Hilbert o_DSE")
print(calc.hilbert_o_dse.reshape(3,3))
# Out:
# Hilbert o_DSE
# [[-8.50179782e-20 -6.75097808e-09 -2.74088600e-03]
#  [ 1.23594531e-19  1.05862536e-04  1.82095059e-03]
#  [-3.85765526e-20 -1.05855785e-04  1.82091640e-03]]

# %%
print(calc.o_dse_gradient.reshape(3,3) - calc.hilbert_o_dse.reshape(3,3))
# Out:
# [[ 0.00000000e+00 -8.27180613e-25  0.00000000e+00]
#  [ 0.00000000e+00  1.35525272e-20  2.16840434e-19]
#  [ 0.00000000e+00 -2.71050543e-20  2.16840434e-19]]

# %%
print(calc.numerical_o_dse_gradient.reshape(3,3))

# %%
calc.calc_dipole_dipole_gradient_2()

# %%
print(calc.K_dse_gradient.reshape(3,3))
# Out:
# [[-2.60426483e-20  1.25026716e-08  8.09991000e-04]
#  [-7.64938539e-21 -3.61150767e-04 -8.55489753e-04]
#  [ 3.36920337e-20  3.61138264e-04 -8.55482237e-04]]

# %%
print(_expected_k_dse)
# Out:
# [[ 1.14641991e-19 -1.20129601e-18  8.09949008e-04]
#  [-5.05409763e-20 -3.61148015e-04 -8.55489341e-04]
#  [-6.41010149e-20  3.61148015e-04 -8.55489341e-04]]

# %%
_total_grad = calc.canonical_gradient + (calc.K_dse_gradient + calc.o_dse_gradient).reshape(3,3)
print("My Analytic QED-RHF Gradient")
print(_total_grad)
# Out:
# My Analytic QED-RHF Gradient
# [[-3.05078252e-16  5.75169396e-09 -8.76870887e-04]
#  [ 1.73948704e-16 -1.96392735e-02  4.38448777e-04]
#  [ 1.31129547e-16  1.96392677e-02  4.38422110e-04]]

# %%
print("My numerical QED-RHF Gradient")
print(calc.numerical_energy_gradient.reshape(3,3))
# Out:
# My numerical QED-RHF Gradient
# [[ 1.12800907e-09 -3.76003023e-10 -8.76898834e-04]
#  [ 0.00000000e+00 -1.96392681e-02  4.38446221e-04]
#  [ 0.00000000e+00  1.96392737e-02  4.38449981e-04]]

# %%
print("The Difference")
print(_total_grad-calc.numerical_energy_gradient.reshape(3,3))

print("Norm of Difference")
error_norm = np.linalg.norm(_total_grad-calc.numerical_energy_gradient.reshape(3,3))
print(error_norm)
# Out:
# The Difference
# [[-1.12800937e-09  6.12769699e-09  2.79470663e-08]
#  [ 1.73948704e-16 -5.40973234e-09  2.55600374e-09]
#  [ 1.31129547e-16 -5.98200451e-09 -2.78710291e-08]]
# Norm of Difference
# 4.084405208352919e-08
