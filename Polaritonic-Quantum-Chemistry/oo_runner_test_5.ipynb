# %% [markdown]
# ## This tests the QED-RHF gradient components against Hilbert's and against numerical components

# %%
from oo_cqed_rhf import CQEDRHFCalculator
import numpy as np
import psi4



### Expected gradients for the backwards displaced O along z
### using our code for all terms in the gradient
_expected_grad_b_psi4_false = np.array(
[[-1.15058861e-16, -8.42176804e-18, -6.22261790e-02],
 [-1.38525048e-17, -4.37161985e-02,  3.11130895e-02],
 [ 1.28911365e-16,  4.37161985e-02,  3.11130895e-02]]
)

### using psi4 with density fitting for the canonical RHF gradient terms
_expected_grad_b_psi4_true = np.array(
[[ 2.25021410e-16,  3.71157596e-06, -6.22221403e-02],
 [-1.24759369e-16, -4.37167489e-02,  3.11127927e-02],
 [-1.00262040e-16, 4.37130373e-02,  3.11093476e-02]]
)

### Expected gradients for the forwards displaced O along z
### using our code for all terms in the gradient
_expected_grad_f_psi4_false = np.array(
[[ 1.78480435e-16, -1.21543163e-16, -6.14182262e-02],
 [-2.46917070e-16, -4.34548055e-02,  3.07091131e-02],
 [ 6.84366355e-17,  4.34548055e-02,  3.07091131e-02]]
)

### using psi4 with density fitting for the canonical RHF gradient terms
_expected_grad_f_psi4_true = np.array(
[[ 1.78480435e-16, -1.37205383e-16, -6.14182262e-02],
 [-2.46917070e-16, -4.34548055e-02,  3.07091131e-02],
 [ 6.84366355e-17,  4.34548055e-02,  3.07091131e-02]]
)

# %%
## backwards displaced geometry string
h2o_string_b = """
         O            0.000000000000     0.000000000000    -0.069000000000
         H            0.000000000000    -0.790689573744     0.543701060715
         H            0.000000000000     0.790689573744     0.543701060715
no_reorient
nocom
symmetry c1
"""

## forward displaced geometry string
h2o_string_f = """
         O            0.000000000000     0.000000000000    -0.068000000000
         H            0.000000000000    -0.790689573744     0.543701060715
         H            0.000000000000     0.790689573744     0.543701060715
no_reorient
nocom
symmetry c1
"""


# lambda vector along z
lambda_vector = np.array([0, 0, 0.05])


# psi4 options
psi4_options = {
    "basis": "cc-pVDZ",
    "save_jk": True,
    "scf_type": "pk",
    "e_convergence": 1e-12,
    "d_convergence": 1e-12,
}

# %%
# instantiate, using forward displaced geometry string... shouldn't matter because
# we will pass our desired geometry string when we want to compute the gradient
calc = CQEDRHFCalculator(lambda_vector, h2o_string_f, psi4_options)

# calculate the CQED-RHF energy and gradient at h2o_string_b, use our routines for all terms
qed_rhf_energy, qed_rhf_grad, g = calc.calc_force_and_energy(h2o_string_b, use_psi4_scf_grad=False)

# test to see if we are close
print(F"\n Pure QED-RHF gradient at backwards displaced geometry passes?\n {np.allclose(qed_rhf_grad, _expected_grad_b_psi4_false, 1e-6, 1e-6)}")

# calculate the CQED-RHF energy and gradient at h2o_string_b, use psi4 with density fitting for canonical terms
qed_rhf_energy, qed_rhf_grad, g = calc.calc_force_and_energy(h2o_string_b, use_psi4_scf_grad=True)

# test to see if we are close
print(F"\n Hybrid Pure-DF QED-RHF gradient at backwards displaced geometry passes?\n {np.allclose(qed_rhf_grad, _expected_grad_b_psi4_true, 1e-6, 1e-6)}")

# calculate the CQED-RHF energy and gradient at h2o_string_f, use our routines for all terms
qed_rhf_energy, qed_rhf_grad, g = calc.calc_force_and_energy(h2o_string_f, use_psi4_scf_grad=False)

# test to see if we are close
print(F"\n Pure  QED-RHF gradient at forward displaced geometry passes?\n {np.allclose(qed_rhf_grad, _expected_grad_f_psi4_false, 1e-6, 1e-6)}")

# calculate the CQED-RHF energy and gradient at h2o_string_b, use psi4 with density fitting for canonical terms
qed_rhf_energy, qed_rhf_grad, g = calc.calc_force_and_energy(h2o_string_b, use_psi4_scf_grad=True)

# test to see if we are close
print(F"\n Hybrid Pure-DF QED-RHF gradient at forward displaced geometry passes?\n {np.allclose(qed_rhf_grad, _expected_grad_f_psi4_true, 1e-6, 1e-6)}")
# Out:
# Not Using Density Fitting!
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Thu Sep 11 11:27:59 2025
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line   198 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry H          line    22 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.069000000000    15.994914619570
#          H            0.000000000000    -0.790689573744     0.543701060715     1.007825032230
#          H            0.000000000000     0.790689573744     0.543701060715     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.08577  B =     13.37733  C =      8.72474 [cm^-1]
#   Rotational constants: A = 752052.31573  B = 401042.16706  C = 261561.12526 [MHz]
#   Nuclear repulsion =    8.798957990260273
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 12
#     Number of basis functions: 24
#     Number of Cartesian functions: 25
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:              12
#       Number of primitives:             32
#       Number of atomic orbitals:        25
#       Number of basis functions:        24
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 90300 doubles for integral storage.
#   We computed 3081 shell quartets total.
#   Whereas there are 3081 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7397523312E-02.
#   Reciprocal condition number of the overlap matrix is 1.0333797901E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         24      24
#    -------------------------
#     Total      24      24
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -75.45101152633583   -7.54510e+01   0.00000e+00
#    @RHF iter   1:   -75.94573726650034   -4.94726e-01   1.74047e-02 ADIIS/DIIS
#    @RHF iter   2:   -75.99958928197468   -5.38520e-02   1.04556e-02 ADIIS/DIIS
#    @RHF iter   3:   -76.02080367591755   -2.12144e-02   1.12266e-03 ADIIS/DIIS
#    @RHF iter   4:   -76.02133578125432   -5.32105e-04   2.41756e-04 ADIIS/DIIS
#    @RHF iter   5:   -76.02136256933865   -2.67881e-05   4.33618e-05 DIIS
#    @RHF iter   6:   -76.02136376306538   -1.19373e-06   6.65973e-06 DIIS
#    @RHF iter   7:   -76.02136379415251   -3.10871e-08   1.05153e-06 DIIS
#    @RHF iter   8:   -76.02136379502477   -8.72262e-10   2.60210e-07 DIIS
#    @RHF iter   9:   -76.02136379508572   -6.09504e-11   4.12807e-08 DIIS
#    @RHF iter  10:   -76.02136379508705   -1.33582e-12   3.57303e-09 DIIS
#    @RHF iter  11:   -76.02136379508700    5.68434e-14   5.86546e-10 DIIS
#    @RHF iter  12:   -76.02136379508704   -4.26326e-14   3.15609e-11 DIIS
#    @RHF iter  13:   -76.02136379508703    1.42109e-14   4.65208e-12 DIIS
#    @RHF iter  14:   -76.02136379508700    2.84217e-14   4.44373e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.557922     2A     -1.316080     3A     -0.676849
#        4A     -0.558760     5A     -0.490383
#
#     Virtual:
#
#        6A      0.177951     7A      0.249441     8A      0.759944
#        9A      0.816053    10A      1.166226    11A      1.198576
#       12A      1.256544    13A      1.452185    14A      1.466151
#       15A      1.667693    16A      1.877127    17A      1.889763
#       18A      2.354146    19A      2.387680    20A      3.248741
#       21A      3.297402    22A      3.453675    23A      3.820765
#       24A      4.098931
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -76.02136379508700
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.7989579902602735
#     One-Electron Energy =                -122.4406567443484164
#     Two-Electron Energy =                  37.6203349590011271
#     Total Energy =                        -76.0213637950870122
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.1869733            1.0117634            0.8247901
#  Magnitude           :                                                    0.8247901
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Thu Sep 11 11:27:59 2025
# Module time:
# 	user time   =       0.18 seconds =       0.00 minutes
# 	system time =       0.03 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.18 seconds =       0.00 minutes
# 	system time =       0.03 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
#
#  Pure QED-RHF gradient at backwards displaced geometry passes?
#  True
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Thu Sep 11 11:28:00 2025
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line   198 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry H          line    22 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.069000000000    15.994914619570
#          H            0.000000000000    -0.790689573744     0.543701060715     1.007825032230
#          H            0.000000000000     0.790689573744     0.543701060715     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.08577  B =     13.37733  C =      8.72474 [cm^-1]
#   Rotational constants: A = 752052.31573  B = 401042.16706  C = 261561.12526 [MHz]
#   Nuclear repulsion =    8.798957990260273
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 12
#     Number of basis functions: 24
#     Number of Cartesian functions: 25
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:              12
#       Number of primitives:             32
#       Number of atomic orbitals:        25
#       Number of basis functions:        24
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 90300 doubles for integral storage.
#   We computed 3081 shell quartets total.
#   Whereas there are 3081 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7397523312E-02.
#   Reciprocal condition number of the overlap matrix is 1.0333797901E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         24      24
#    -------------------------
#     Total      24      24
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -75.45101152633583   -7.54510e+01   0.00000e+00
#    @RHF iter   1:   -75.94573726650034   -4.94726e-01   1.74047e-02 ADIIS/DIIS
#    @RHF iter   2:   -75.99958928197468   -5.38520e-02   1.04556e-02 ADIIS/DIIS
#    @RHF iter   3:   -76.02080367591755   -2.12144e-02   1.12266e-03 ADIIS/DIIS
#    @RHF iter   4:   -76.02133578125432   -5.32105e-04   2.41756e-04 ADIIS/DIIS
#    @RHF iter   5:   -76.02136256933865   -2.67881e-05   4.33618e-05 DIIS
#    @RHF iter   6:   -76.02136376306538   -1.19373e-06   6.65973e-06 DIIS
#    @RHF iter   7:   -76.02136379415251   -3.10871e-08   1.05153e-06 DIIS
#    @RHF iter   8:   -76.02136379502477   -8.72262e-10   2.60210e-07 DIIS
#    @RHF iter   9:   -76.02136379508572   -6.09504e-11   4.12807e-08 DIIS
#    @RHF iter  10:   -76.02136379508705   -1.33582e-12   3.57303e-09 DIIS
#    @RHF iter  11:   -76.02136379508700    5.68434e-14   5.86546e-10 DIIS
#    @RHF iter  12:   -76.02136379508704   -4.26326e-14   3.15609e-11 DIIS
#    @RHF iter  13:   -76.02136379508703    1.42109e-14   4.65208e-12 DIIS
#    @RHF iter  14:   -76.02136379508700    2.84217e-14   4.44373e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.557922     2A     -1.316080     3A     -0.676849
#        4A     -0.558760     5A     -0.490383
#
#     Virtual:
#
#        6A      0.177951     7A      0.249441     8A      0.759944
#        9A      0.816053    10A      1.166226    11A      1.198576
#       12A      1.256544    13A      1.452185    14A      1.466151
#       15A      1.667693    16A      1.877127    17A      1.889763
#       18A      2.354146    19A      2.387680    20A      3.248741
#       21A      3.297402    22A      3.453675    23A      3.820765
#       24A      4.098931
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -76.02136379508700
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.7989579902602735
#     One-Electron Energy =                -122.4406567443484164
#     Two-Electron Energy =                  37.6203349590011271
#     Total Energy =                        -76.0213637950870122
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.1869733            1.0117634            0.8247901
#  Magnitude           :                                                    0.8247901
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Thu Sep 11 11:28:00 2025
# Module time:
# 	user time   =       0.23 seconds =       0.00 minutes
# 	system time =       1.88 seconds =       0.03 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       1.23 seconds =       0.02 minutes
# 	system time =       4.83 seconds =       0.08 minutes
# 	total time  =          1 seconds =       0.02 minutes
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Thu Sep 11 11:28:00 2025
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.069000000000    15.994914619570
#          H            0.000000000000    -0.790689573744     0.543701060715     1.007825032230
#          H            0.000000000000     0.790689573744     0.543701060715     1.007825032230
#
#   Nuclear repulsion =    8.79895799026027
#  Hybrid Pure-DF QED-RHF gradient at backwards displaced geometry passes?
#  False
# 3
#
#   ==> Basis Set <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 12
#     Number of basis functions: 24
#     Number of Cartesian functions: 25
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.000000000000     0.000000000000    -0.060519544031
#        2        0.000000000000    -0.043518923088     0.030259772016
#        3        0.000000000000     0.043518923088     0.030259772016
#
#
# *** tstop() called on CHEM9QDFT72ALT at Thu Sep 11 11:28:00 2025
# Module time:
# 	user time   =       0.07 seconds =       0.00 minutes
# 	system time =       0.21 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       1.83 seconds =       0.03 minutes
# 	system time =       6.59 seconds =       0.11 minutes
# 	total time  =          1 seconds =       0.02 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Thu Sep 11 11:28:00 2025
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line   198 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry H          line    22 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.068000000000    15.994914619570
#          H            0.000000000000    -0.790689573744     0.543701060715     1.007825032230
#          H            0.000000000000     0.790689573744     0.543701060715     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.16783  B =     13.37733  C =      8.73465 [cm^-1]
#   Rotational constants: A = 754512.68272  B = 401042.16706  C = 261858.10341 [MHz]
#   Nuclear repulsion =    8.804141549537034
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 12
#     Number of basis functions: 24
#     Number of Cartesian functions: 25
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:              12
#       Number of primitives:             32
#       Number of atomic orbitals:        25
#       Number of basis functions:        24
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 90300 doubles for integral storage.
#   We computed 3081 shell quartets total.
#   Whereas there are 3081 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7366368886E-02.
#   Reciprocal condition number of the overlap matrix is 1.0323603670E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         24      24
#    -------------------------
#     Total      24      24
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -75.45178417761444   -7.54518e+01   0.00000e+00
#    @RHF iter   1:   -75.94591376393647   -4.94130e-01   1.74034e-02 ADIIS/DIIS
#    @RHF iter   2:   -75.99974589827373   -5.38321e-02   1.04457e-02 ADIIS/DIIS
#    @RHF iter   3:   -76.02091753970019   -2.11716e-02   1.12173e-03 ADIIS/DIIS
#    @RHF iter   4:   -76.02144847387457   -5.30934e-04   2.41215e-04 ADIIS/DIIS
#    @RHF iter   5:   -76.02147514586736   -2.66720e-05   4.33085e-05 DIIS
#    @RHF iter   6:   -76.02147633786436   -1.19200e-06   6.66775e-06 DIIS
#    @RHF iter   7:   -76.02147636911558   -3.12512e-08   1.05591e-06 DIIS
#    @RHF iter   8:   -76.02147636999662   -8.81045e-10   2.60552e-07 DIIS
#    @RHF iter   9:   -76.02147637005760   -6.09788e-11   4.11112e-08 DIIS
#    @RHF iter  10:   -76.02147637005891   -1.30740e-12   3.55894e-09 DIIS
#    @RHF iter  11:   -76.02147637005895   -4.26326e-14   5.85192e-10 DIIS
#    @RHF iter  12:   -76.02147637005893    1.42109e-14   3.15554e-11 DIIS
#    @RHF iter  13:   -76.02147637005896   -2.84217e-14   4.64208e-12 DIIS
#    @RHF iter  14:   -76.02147637005891    5.68434e-14   4.42175e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.557764     2A     -1.316288     3A     -0.677313
#        4A     -0.558690     5A     -0.490382
#
#     Virtual:
#
#        6A      0.178076     7A      0.249542     8A      0.760627
#        9A      0.816186    10A      1.166136    11A      1.198649
#       12A      1.256386    13A      1.452875    14A      1.466008
#       15A      1.668227    16A      1.877171    17A      1.889895
#       18A      2.355708    19A      2.388934    20A      3.248832
#       21A      3.298295    22A      3.454094    23A      3.822006
#       24A      4.099157
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -76.02147637005891
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8041415495370341
#     One-Electron Energy =                -122.4503611516845041
#     Two-Electron Energy =                  37.6247432320885622
#     Total Energy =                        -76.0214763700589060
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -0.2028536            1.0268812            0.8240276
#  Magnitude           :                                                    0.8240276
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Thu Sep 11 11:28:00 2025
# Module time:
# 	user time   =       0.26 seconds =       0.00 minutes
# 	system time =       2.31 seconds =       0.04 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       2.18 seconds =       0.04 minutes
# 	system time =       9.57 seconds =       0.16 minutes
# 	total time  =          1 seconds =       0.02 minutes
#
#  Pure  QED-RHF gradient at forward displaced geometry passes?
#  True
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Thu Sep 11 11:28:01 2025
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line   198 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry H          line    22 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.069000000000    15.994914619570
#          H            0.000000000000    -0.790689573744     0.543701060715     1.007825032230
#          H            0.000000000000     0.790689573744     0.543701060715     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     25.08577  B =     13.37733  C =      8.72474 [cm^-1]
#   Rotational constants: A = 752052.31573  B = 401042.16706  C = 261561.12526 [MHz]
#   Nuclear repulsion =    8.798957990260273
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-12
#   Density threshold  = 1.00e-12
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 12
#     Number of basis functions: 24
#     Number of Cartesian functions: 25
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   3
#       Number of AO shells:              12
#       Number of primitives:             32
#       Number of atomic orbitals:        25
#       Number of basis functions:        24
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 90300 doubles for integral storage.
#   We computed 3081 shell quartets total.
#   Whereas there are 3081 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.7397523312E-02.
#   Reciprocal condition number of the overlap matrix is 1.0333797901E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         24      24
#    -------------------------
#     Total      24      24
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -75.45101152633583   -7.54510e+01   0.00000e+00
#    @RHF iter   1:   -75.94573726650034   -4.94726e-01   1.74047e-02 ADIIS/DIIS
#    @RHF iter   2:   -75.99958928197468   -5.38520e-02   1.04556e-02 ADIIS/DIIS
#    @RHF iter   3:   -76.02080367591755   -2.12144e-02   1.12266e-03 ADIIS/DIIS
#    @RHF iter   4:   -76.02133578125432   -5.32105e-04   2.41756e-04 ADIIS/DIIS
#    @RHF iter   5:   -76.02136256933865   -2.67881e-05   4.33618e-05 DIIS
#    @RHF iter   6:   -76.02136376306538   -1.19373e-06   6.65973e-06 DIIS
#    @RHF iter   7:   -76.02136379415251   -3.10871e-08   1.05153e-06 DIIS
#    @RHF iter   8:   -76.02136379502477   -8.72262e-10   2.60210e-07 DIIS
#    @RHF iter   9:   -76.02136379508572   -6.09504e-11   4.12807e-08 DIIS
#    @RHF iter  10:   -76.02136379508705   -1.33582e-12   3.57303e-09 DIIS
#    @RHF iter  11:   -76.02136379508700    5.68434e-14   5.86546e-10 DIIS
#    @RHF iter  12:   -76.02136379508704   -4.26326e-14   3.15609e-11 DIIS
#    @RHF iter  13:   -76.02136379508703    1.42109e-14   4.65208e-12 DIIS
#    @RHF iter  14:   -76.02136379508700    2.84217e-14   4.44373e-13 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.557922     2A     -1.316080     3A     -0.676849
#        4A     -0.558760     5A     -0.490383
#
#     Virtual:
#
#        6A      0.177951     7A      0.249441     8A      0.759944
#        9A      0.816053    10A      1.166226    11A      1.198576
#       12A      1.256544    13A      1.452185    14A      1.466151
#       15A      1.667693    16A      1.877127    17A      1.889763
#       18A      2.354146    19A      2.387680    20A      3.248741
#       21A      3.297402    22A      3.453675    23A      3.820765
#       24A      4.098931
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#     NA   [     5 ]
#     NB   [     5 ]
#
#   @RHF Final Energy:   -76.02136379508700
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.7989579902602735
#     One-Electron Energy =                -122.4406567443484164
#     Two-Electron Energy =                  37.6203349590011271
#     Total Energy =                        -76.0213637950870122
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.1869733            1.0117634            0.8247901
#  Magnitude           :                                                    0.8247901
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Thu Sep 11 11:28:01 2025
# Module time:
# 	user time   =       0.23 seconds =       0.00 minutes
# 	system time =       1.98 seconds =       0.03 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       3.26 seconds =       0.05 minutes
# 	system time =      15.06 seconds =       0.25 minutes
# 	total time  =          2 seconds =       0.03 minutes
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Thu Sep 11 11:28:01 2025
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.000000000000    -0.069000000000    15.994914619570
#          H            0.000000000000    -0.790689573744     0.543701060715     1.007825032230
#          H            0.000000000000     0.790689573744     0.543701060715     1.007825032230
#
#   Nuclear repulsion =    8.798957990260273
#
#   ==> Basis Set <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 12
#     Number of basis functions: 24
#     Number of Cartesian functions: 25
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DirectJKGrad: Integral-Direct SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Integrals threads:           1
#     Schwarz Cutoff:          1E-12
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.000000000000     0.000000000000    -0.060519544031
#        2        0.000000000000    -0.043518923088     0.030259772016
#        3        0.000000000000     0.043518923088     0.030259772016
#
#
# *** tstop() called on CHEM9QDFT72ALT at Thu Sep 11 11:28:01 2025
# Module time:
# 	user time   =       0.11 seconds =
#  Hybrid Pure-DF QED-RHF gradient at forward displaced geometry passes?
#  False
# 0.00 minutes
# 	system time =       0.30 seconds =       0.01 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       3.58 seconds =       0.06 minutes
# 	system time =      15.76 seconds =       0.26 minutes
# 	total time  =          2 seconds =       0.03 minutes
